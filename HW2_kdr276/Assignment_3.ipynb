# %%
from __future__ import print_function
import os
import numpy as np
import pandas as pd
#import seaborn
import pylab as pl

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
os.getenv('DFDATA')
# Out:
# '/gws/open/NYCOpenData/nycopendata/data'

# %%
DFDATA = os.getenv('DFDATA')

# %%
#.csv location not directly in cusp data
df1 = pd.read_csv("https://data.cityofnewyork.us/resource/pasr-j7fb.csv")
#df1 = pd.read_csv('DFDATA' + "/pasr-j7fb/resource/5c0d0640-e842-487a-bd49-e8662c7ed59b")
df1.columns
# Out:
# Index([u'Incident Type', u'Location', u'Borough', u'Creation Date',
#        u'Closed Date', u'Latitude', u'Longitude'],
#       dtype='object')

# %%
df1.head()
# Out:
#                        Incident Type                   Location    Borough  \
# 0                Structural-Collapse           315 East 166 St.      Bronx
# 1        HazMat-High Carbon Monoxide  East 69 Street & Avenue L   Brooklyn
# 2  LawEnforcement-Suspicious Package         542 West 22 Street  Manhattan
# 3           Utility-Gas Main Rupture              1000 Broadway   Brooklyn
# 4                     Fire-2nd Alarm             422 West 57 St  Manhattan
#
#             Creation Date             Closed Date   Latitude  Longitude
# 0  04/05/2014 06:13:12 PM  05/09/2014 07:34:47 AM  40.830077 -73.914192
# 1  05/09/2014 11:37:51 AM  05/09/2014 01:02:13 PM  40.625297 -73.915988
# 2  05/09/2014 05:31:59 PM  05/09/2014 06:05:19 PM  40.714430 -74.006096
# 3  05/12/2014 03:31:27 PM  05/12/2014 06:40:51 PM  40.696046 -73.933664
# 4  05/12/2014 03:51:25 PM  05/12/2014 06:45:02 PM  40.714430 -74.006096

# %%
df2 = df1.drop([u'Incident Type', u'Location', u'Borough', u'Creation Date',
       u'Closed Date'], axis = 1)
df2.head()
# Out:
#     Latitude  Longitude
# 0  40.830077 -73.914192
# 1  40.625297 -73.915988
# 2  40.714430 -74.006096
# 3  40.696046 -73.933664
# 4  40.714430 -74.006096

# %%
ax = df2.plot.scatter(x='Longitude', y='Latitude', alpha=0.2)
ax.set_title("Emergency Response Incident Locations")

# %% [markdown]
# ### Figure 1:
#
# OEM emergency incident response mapped by Geographical Coordinates (Long and Lat)
